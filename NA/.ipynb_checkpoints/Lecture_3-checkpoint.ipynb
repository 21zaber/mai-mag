# %%
from numpy import array, arange, abs as np_abs
from numpy.fft import rfft, rfftfreq
from math import sin, pi, cos, sqrt
import matplotlib.pyplot as plt
import matplotlib as mpl

N = 1000
w = (2 * pi / N)
A = 2
B = 4
#sin_sig = array([A * sin(4 * w * t) + B * cos(9 * w * t)  for t in range(N)])
sin_sig = array([A * sin(6 * w * t) + B * cos(12 * w * t) + 3* A * sin(2 * w * t) + 5 * B * cos(1 * w * t) for t in range(N)])
plt.plot(arange(N), sin_sig, 'r')
plt.grid(True)
plt.show()

# %%
import math
import cmath

def DFT(fnList):
    N = len(fnList)
    FmList = []
    for m in range(N):
        Fm = 0.0
        for n in range(N):
            Fm += fnList[n] * cmath.exp(1j * 2.0 * math.pi  * m * n / N)
        #FmList.append(Fm)
        FmList.append(Fm / N)
    return FmList

def InverseDFT(FmList):
    N = len(FmList)
    fnList = []
    for n in range(N):
        fn = 0.0
        for m in range(N):
            fn += FmList[m] * cmath.exp(-1j * 2.0 * math.pi  * m * n / N)
        #fnList.append(fn / N)
        fnList.append(fn)
    return fnList

# %%
I = DFT(sin_sig)

# %%
M = []
for i in range(len(I)):
    M.append(sqrt(I[i].real**2 + I[i].imag**2) * 2)

plt.plot(arange(N), M, 'ro')
plt.grid(True)
plt.show()

# %%
plt.plot(arange(N / 20), M[0:int(N / 20)], 'ro')
plt.grid(True)
plt.show()

# %%
for i in range(int(N / 20)):
    if (I[i] > 1 / N or I[i] < -1 / N):
        print(I[i])
        print(i)
# Out:
# (10.000000000000002+8.621992009238966e-16j)
# 1
# (1.9999999999999987-2.5364155220586326e-15j)
# 12

# %%
H = InverseDFT(I)

# %%
plt.plot(arange(N), H, 'r')
plt.grid(True)
plt.show()

# %%
def FDFT(fnList):
    N = len(fnList)
    FmList = []
    for m in range(N):
        Fm = 0.0
        for n in range(N):
            Fm += fnList[n] * cmath.exp(- 1j * 2.0 * math.pi  * m * n / N)
        #FmList.append(Fm)
        #if(Fm / N > 0.00848 or Fm / N < -0.00848):
        if(Fm / N > 0.01 or Fm / N < -0.01):
            FmList.append(Fm / N)
    return FmList

# %%
FI = FDFT(sin_sig)

# %%
plt.plot(arange(len(FI)), I[0:len(FI)], 'ro')
plt.grid(True)
plt.show()

# %%
for i in range(len(FI)):
    print(FI[i])
    print(i)
# Out:
# (-0.0519984642828789+0j)
# 0
# (-0.052697285367401765+0.008368069507506078j)
# 1
# (-0.05491072243897967+0.017436491835109848j)
# 2
# (-0.05904231675287488-2.7218843478623613j)
# 3
# (-0.06598940328175+0.04188378643561378j)
# 4
# (-0.07774069490168467+0.061650287830663154j)
# 5
# (-0.09934081965948341+0.0944838082910117j)
# 6
# (-0.14782283271053628+0.16392172618101156j)
# 7
# (-0.3377535194905415+0.4277227141887737j)
# 8
# (0.744195639488909-1.0593380789047695j)
# 9
# (0.1627071992418642-0.2570995787228029j)
# 10
# (0.08738773221134218-0.1517346079186699j)
# 11
# (0.05803040908308046-0.10979502347741454j)
# 12
# (0.04253530497779862-0.08707640705412047j)
# 13
# (0.033033615954919104-0.07272961039693136j)
# 14
# (0.02665576537833862-0.06278948217984905j)
# 15
# (0.022106723347509533-0.05546056176086487j)
# 16
# (0.018717112230962365-0.04981054907864505j)
# 17
# (0.016106576852450694-0.045306594416219j)
# 18
# (0.014043300099985633-0.04162164128247805j)
# 19
# (0.012378146741920766-0.03854354828722125j)
# 20
# (0.0110109565937686-0.03592850824858498j)
# 21
# (0.011010956593843909+0.03592850824868475j)
# 22
# (0.012378146741923498+0.038543548287215186j)
# 23
# (0.01404330009995022+0.041621641282537154j)
# 24
# (0.016106576852397143+0.045306594416371554j)
# 25
# (0.01871711223095333+0.04981054907868897j)
# 26
# (0.022106723347476338+0.0554605617610069j)
# 27
# (0.026655765378340322+0.06278948217985258j)
# 28
# (0.033033615954840626+0.07272961039709863j)
# 29
# (0.04253530497770481+0.08707640705442693j)
# 30
# (0.058030409083034536+0.10979502347754097j)
# 31
# (0.08738773221119166+0.1517346079191278j)
# 32
# (0.16270719924184163+0.2570995787228396j)
# 33
# (0.7441956394867743+1.0593380789055291j)
# 34
# (-0.33775351949087135-0.42772271418844365j)
# 35
# (-0.14782283271052493-0.16392172618119055j)
# 36
# (-0.09934081965941179-0.09448380829107625j)
# 37
# (-0.07774069490167158-0.06165028783061079j)
# 38
# (-0.06598940328172621-0.041883786434485266j)
# 39
# (-0.059042316751944934+2.721884347862447j)
# 40
# (-0.05491072243888339-0.017436491836513933j)
# 41
# (-0.05269728536740393-0.00836806950953401j)
# 42

# %%
FH = InverseDFT(FI)
#FH[0] = B #амплитуда косинуса в нуле

# %%
TH = []
for i in range(len(H)):
    if(i % int(len(H) / len(FH)) == 0):
        TH.append(H[i])

# %%
plt.plot(arange(len(FH)), FH, 'r')
plt.plot(arange(len(FH)), TH[0:len(FH)], 'b--')
plt.grid(True)
plt.show()

# %%
diff = []
for i in range(len(FH)):
    diff.append(abs(FH[i] - TH[i]))
    
plt.plot(arange(len(diff)), diff, 'r')
plt.grid(True)
plt.show()
